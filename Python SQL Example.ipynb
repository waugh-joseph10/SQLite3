# %%
#Import libraries
import numpy as np
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt

#Set up Directory 
database = r'C:/Users/HP/Desktop/database.sqlite'

# %%
#Connect to database, and read in tables
conn = sqlite3.connect(database)
tables = pd.read_sql("""SELECT *
                        FROM sqlite_master
                        WHERE type='table';""", conn)
tables
# Out:
#     type               name           tbl_name  rootpage  \
# 0  table    sqlite_sequence    sqlite_sequence         4
# 1  table  Player_Attributes  Player_Attributes        11
# 2  table             Player             Player        14
# 3  table              Match              Match        18
# 4  table             League             League        24
# 5  table            Country            Country        26
# 6  table               Team               Team        29
# 7  table    Team_Attributes    Team_Attributes         2
#
#                                                  sql
# 0             CREATE TABLE sqlite_sequence(name,seq)
# 1  CREATE TABLE "Player_Attributes" (\n\t`id`\tIN...
# 2  CREATE TABLE `Player` (\n\t`id`\tINTEGER PRIMA...
# 3  CREATE TABLE `Match` (\n\t`id`\tINTEGER PRIMAR...
# 4  CREATE TABLE `League` (\n\t`id`\tINTEGER PRIMA...
# 5  CREATE TABLE `Country` (\n\t`id`\tINTEGER PRIM...
# 6  CREATE TABLE "Team" (\n\t`id`\tINTEGER PRIMARY...
# 7  CREATE TABLE `Team_Attributes` (\n\t`id`\tINTE...

# %%
#Country List
countries = pd.read_sql("""SELECT * FROM Country;""", conn)
countries
# Out:
#        id         name
# 0       1      Belgium
# 1    1729      England
# 2    4769       France
# 3    7809      Germany
# 4   10257        Italy
# 5   13274  Netherlands
# 6   15722       Poland
# 7   17642     Portugal
# 8   19694     Scotland
# 9   21518        Spain
# 10  24558  Switzerland

# %%
#List of Leagues and Countries
leagues = pd.read_sql("""SELECT * 
                         FROM League
                         JOIN Country ON Country.id = League.country_id""", conn)
leagues
# Out:
#        id  country_id                      name     id         name
# 0       1           1    Belgium Jupiler League      1      Belgium
# 1    1729        1729    England Premier League   1729      England
# 2    4769        4769            France Ligue 1   4769       France
# 3    7809        7809     Germany 1. Bundesliga   7809      Germany
# 4   10257       10257             Italy Serie A  10257        Italy
# 5   13274       13274    Netherlands Eredivisie  13274  Netherlands
# 6   15722       15722        Poland Ekstraklasa  15722       Poland
# 7   17642       17642  Portugal Liga ZON Sagres  17642     Portugal
# 8   19694       19694   Scotland Premier League  19694     Scotland
# 9   21518       21518           Spain LIGA BBVA  21518        Spain
# 10  24558       24558  Switzerland Super League  24558  Switzerland

# %%
#List of Teams 
teams = pd.read_sql("""SELECT * 
                       FROM Team 
                       ORDER BY team_long_name
                       LIMIT 20""", conn)
teams
# Out:
#        id  team_api_id  team_fifa_api_id        team_long_name team_short_name
# 0   16848         8350              29.0  1. FC Kaiserslautern             KAI
# 1   15624         8722              31.0            1. FC Köln             FCK
# 2   16239         8165             171.0        1. FC Nürnberg             NUR
# 3   16243         9905             169.0       1. FSV Mainz 05             MAI
# 4   11817         8576             614.0            AC Ajaccio             AJA
# 5   11074       108893          111989.0      AC Arles-Avignon             ARL
# 6   49116         6493            1714.0         AC Bellinzona             BEL
# 7   26560        10217             650.0          ADO Den Haag             HAA
# 8    9537         8583              57.0            AJ Auxerre             AUX
# 9    9547         9829              69.0             AS Monaco             MON
# 10   9549         8481            1823.0     AS Nancy-Lorraine             NAN
# 11   9556         9853            1819.0      AS Saint-Étienne             ETI
# 12  26563        10229            1906.0                    AZ             ALK
# 13  39393         8485              77.0              Aberdeen             ABE
# 14  35292        10215            1901.0  Académica de Coimbra             ACA
# 15  26552         8593             245.0                  Ajax             AJA
# 16  35291        10213               NaN               Amadora             AMA
# 17  14868         8121            1530.0            Angers SCO             ANG
# 18  31455         8322          111082.0           Arka Gdynia             ARK
# 19   3459         9825               1.0               Arsenal             ARS

# %%
#Match Detailed Information
detailed_matches = pd.read_sql("""SELECT Match.id, 
                                        Country.name AS country_name,
                                        League.name AS league_name, 
                                        season, 
                                        stage,
                                        date, 
                                        HT.team_long_name AS home_team,
                                        AT.team_long_name AS away_team,
                                        home_team_goal, 
                                        away_team_goal
                                  FROM Match
                                  JOIN Country on Country.id = Match.country_id
                                  JOIN League on League.id = Match.league_id
                                  LEFT JOIN Team AS HT on HT.team_api_id = Match.home_team_api_id
                                  LEFT JOIN Team AS AT on AT.team_api_id = Match.away_team_api_id
                                  WHERE country_name = 'England'
                                  ORDER by date
                                  LIMIT 10;""", conn)
detailed_matches
# Out:
#      id country_name             league_name     season  stage  \
# 0  1730      England  England Premier League  2008/2009      1
# 1  1731      England  England Premier League  2008/2009      1
# 2  1732      England  England Premier League  2008/2009      1
# 3  1734      England  England Premier League  2008/2009      1
# 4  1735      England  England Premier League  2008/2009      1
# 5  1736      England  England Premier League  2008/2009      1
# 6  1737      England  England Premier League  2008/2009      1
# 7  1729      England  England Premier League  2008/2009      1
# 8  1733      England  England Premier League  2008/2009      1
# 9  1738      England  England Premier League  2008/2009      1
#
#                   date          home_team             away_team  \
# 0  2008-08-16 00:00:00            Arsenal  West Bromwich Albion
# 1  2008-08-16 00:00:00         Sunderland             Liverpool
# 2  2008-08-16 00:00:00    West Ham United        Wigan Athletic
# 3  2008-08-16 00:00:00            Everton      Blackburn Rovers
# 4  2008-08-16 00:00:00      Middlesbrough     Tottenham Hotspur
# 5  2008-08-16 00:00:00   Bolton Wanderers            Stoke City
# 6  2008-08-16 00:00:00          Hull City                Fulham
# 7  2008-08-17 00:00:00  Manchester United      Newcastle United
# 8  2008-08-17 00:00:00        Aston Villa       Manchester City
# 9  2008-08-17 00:00:00            Chelsea            Portsmouth
#
#    home_team_goal  away_team_goal
# 0               1               0
# 1               0               1
# 2               2               1
# 3               2               3
# 4               2               1
# 5               3               1
# 6               2               1
# 7               1               1
# 8               4               2
# 9               4               0

# %%
#League Information from Season
leagues_by_season = pd.read_sql("""SELECT Country.name AS country_name, 
                                        League.name AS league_name, 
                                        season,
                                        count(distinct stage) AS number_of_stages,
                                        count(distinct HT.team_long_name) AS number_of_teams,
                                        avg(home_team_goal) AS avg_home_team_scors, 
                                        avg(away_team_goal) AS avg_away_team_goals, 
                                        avg(home_team_goal-away_team_goal) AS avg_goal_dif, 
                                        avg(home_team_goal+away_team_goal) AS avg_goals, 
                                        sum(home_team_goal+away_team_goal) AS total_goals                                       
                                FROM Match
                                JOIN Country on Country.id = Match.country_id
                                JOIN League on League.id = Match.league_id
                                LEFT JOIN Team AS HT on HT.team_api_id = Match.home_team_api_id
                                LEFT JOIN Team AS AT on AT.team_api_id = Match.away_team_api_id
                                WHERE country_name in ('Spain', 'Germany', 'France', 'Italy', 'England')
                                GROUP BY Country.name, League.name, season
                                HAVING count(distinct stage) > 10
                                ORDER BY Country.name, League.name, season DESC
                                ;""", conn)
leagues_by_season
# Out:
#    country_name             league_name     season  number_of_stages  \
# 0       England  England Premier League  2015/2016                38
# 1       England  England Premier League  2014/2015                38
# 2       England  England Premier League  2013/2014                38
# 3       England  England Premier League  2012/2013                38
# 4       England  England Premier League  2011/2012                38
# 5       England  England Premier League  2010/2011                38
# 6       England  England Premier League  2009/2010                38
# 7       England  England Premier League  2008/2009                38
# 8        France          France Ligue 1  2015/2016                38
# 9        France          France Ligue 1  2014/2015                38
# 10       France          France Ligue 1  2013/2014                38
# 11       France          France Ligue 1  2012/2013                38
# 12       France          France Ligue 1  2011/2012                38
# 13       France          France Ligue 1  2010/2011                38
# 14       France          France Ligue 1  2009/2010                38
# 15       France          France Ligue 1  2008/2009                38
# 16      Germany   Germany 1. Bundesliga  2015/2016                34
# 17      Germany   Germany 1. Bundesliga  2014/2015                34
# 18      Germany   Germany 1. Bundesliga  2013/2014                34
# 19      Germany   Germany 1. Bundesliga  2012/2013                34
# 7    2.478947          942
# 8    2.526316          960
# 9    2.492105          947
# 10   2.455263          933
# 11   2.544737          967
# 12   2.515789          956
# 13   2.342105          890
# 14   2.410526          916
# 15   2.257895          858
# 16   2.830065          866
# 17   2.754902          843
# 18   3.160131          967
# 19   2.934641          898
# 20   2.859477          875
# 21   2.921569          894
# 22   2.830065          866
# 23   2.921569          894
# 24   2.576316          979
# 25   2.686016         1018
# 26   2.723684         1035
# 27   2.639474         1003
# 28   2.583799          925
# 29   2.513158          955
# 30   2.610526          992
# 31   2.600000          988
# 32   2.744737         1043
# 33   2.655263         1009
# 34   2.750000         1045
# 35   2.871053         1091
# 36   2.763158         1050
# 37   2.742105         1042
# 38   2.713158         1031
# 39   2.897368         1101

# %%
df = pd.DataFrame(index=np.sort(leagues_by_season['season'].unique()), columns=leagues_by_season['country_name'].unique())

df.loc[:,'Germany'] = list(leagues_by_season.loc[leagues_by_season['country_name']=='Germany','avg_goals'])
df.loc[:,'Spain']   = list(leagues_by_season.loc[leagues_by_season['country_name']=='Spain','avg_goals'])
df.loc[:,'France']   = list(leagues_by_season.loc[leagues_by_season['country_name']=='France','avg_goals'])
df.loc[:,'Italy']   = list(leagues_by_season.loc[leagues_by_season['country_name']=='Italy','avg_goals'])
df.loc[:,'England']   = list(leagues_by_season.loc[leagues_by_season['country_name']=='England','avg_goals'])

df.plot(figsize=(12,5),title='Average Goals per Game')

# %%
df = pd.DataFrame(index=np.sort(leagues_by_season['season'].unique()), columns=leagues_by_season['country_name'].unique())

df.loc[:,'Germany'] = list(leagues_by_season.loc[leagues_by_season['country_name']=='Germany','avg_goal_dif'])
df.loc[:,'Spain']   = list(leagues_by_season.loc[leagues_by_season['country_name']=='Spain','avg_goal_dif'])
df.loc[:,'France']   = list(leagues_by_season.loc[leagues_by_season['country_name']=='France','avg_goal_dif'])
df.loc[:,'Italy']   = list(leagues_by_season.loc[leagues_by_season['country_name']=='Italy','avg_goal_dif'])
df.loc[:,'England']   = list(leagues_by_season.loc[leagues_by_season['country_name']=='England','avg_goal_dif'])

df.plot(figsize=(12,5),title='Average Goals Difference: Home vs Away')

# %%
players_weight = pd.read_sql("""SELECT CASE
                                        WHEN ROUND(weight)<165 then 165
                                        WHEN ROUND(weight)>215 then 215
                                        ELSE ROUND(weight)
                                        END AS calc_weight, 
                                        COUNT(weight) AS distribution, 
                                        (avg(PA_Grouped.avg_overall_rating)) AS avg_overall_rating,
                                        (avg(PA_Grouped.avg_potential)) AS avg_potential,
                                        AVG(height) AS avg_height 
                            FROM PLAYER
                            LEFT JOIN (SELECT Player_Attributes.player_api_id, 
                                        avg(Player_Attributes.overall_rating) AS avg_overall_rating,
                                        avg(Player_Attributes.potential) AS avg_potential  
                                        FROM Player_Attributes
                                        GROUP BY Player_Attributes.player_api_id) 
                                        AS PA_Grouped ON PLAYER.player_api_id = PA_Grouped.player_api_id
                            GROUP BY calc_weight
                            ORDER BY calc_weight
                                ;""", conn)
players_weight
# Out:
#     calc_weight  distribution  avg_overall_rating  avg_potential  avg_height
# 0         165.0          5203           66.285269      72.084628  177.610586
# 1         168.0           600           66.692551      72.043486  182.046033
# 2         170.0           551           66.627925      71.894661  182.386751
# 3         172.0           656           66.963726      71.975594  183.363994
# 4         174.0           488           66.937069      71.540667  183.874139
# 5         176.0           697           67.192801      72.126052  184.982697
# 6         179.0           375           67.152720      71.561417  185.000053
# 7         181.0           441           67.372036      72.128941  186.347302
# 8         183.0           404           67.578004      72.212919  186.822030
# 9         185.0           343           67.615200      72.171466  187.671195
# 10        187.0           310           67.556509      72.252760  188.279548
# 11        190.0           202           67.785818      72.221483  188.425248
# 12        192.0           148           67.770202      72.362560  188.989730
# 13        194.0           160           68.444912      73.158388  190.230125
# 14        196.0           107           67.325102      71.910972  190.286355
# 15        198.0           132           69.015168      73.551066  190.981061
# 16        201.0            53           67.643276      71.792654  191.554340
# 17        203.0            60           70.184674      73.615371  191.770000
# 18        205.0            35           67.138990      71.530407  192.314286
# 19        207.0            26           68.237822      72.871873  193.430769
# 20        209.0            28           71.106485      74.348634  194.763571
# 21        212.0            18           66.895702      71.198336  194.451111
# 22        214.0             7           67.860410      71.448573  192.677143
# 23        215.0            16           68.663105      72.460171  196.532500

# %%
players_weight.plot(y=['avg_overall_rating'],figsize=(12,5),title='Potential vs Weight')

# %%
players_height = pd.read_sql("""SELECT CASE
                                        WHEN ROUND(height)<165 then 165
                                        WHEN ROUND(height)>195 then 195
                                        ELSE ROUND(height)
                                        END AS calc_height, 
                                        COUNT(height) AS distribution, 
                                        (avg(PA_Grouped.avg_overall_rating)) AS avg_overall_rating,
                                        (avg(PA_Grouped.avg_potential)) AS avg_potential,
                                        AVG(weight) AS avg_weight 
                            FROM PLAYER
                            LEFT JOIN (SELECT Player_Attributes.player_api_id, 
                                        avg(Player_Attributes.overall_rating) AS avg_overall_rating,
                                        avg(Player_Attributes.potential) AS avg_potential  
                                        FROM Player_Attributes
                                        GROUP BY Player_Attributes.player_api_id) 
                                        AS PA_Grouped ON PLAYER.player_api_id = PA_Grouped.player_api_id
                            GROUP BY calc_height
                            ORDER BY calc_height
                                ;""", conn)
players_height
# Out:
#     calc_height  distribution  avg_overall_rating  avg_potential  avg_weight
# 0         165.0            74           67.365543      73.327754  139.459459
# 1         168.0           118           67.500518      73.124182  144.127119
# 2         170.0           403           67.726903      73.379056  147.799007
# 3         173.0           530           66.980272      72.848746  152.824528
# 4         175.0          1188           66.805204      72.258774  156.111953
# 5         178.0          1489           66.367212      71.943339  160.665547
# 6         180.0          1388           66.419053      71.846394  165.261527
# 7         183.0          1954           66.634380      71.754555  170.167861
# 8         185.0          1278           66.928964      71.833475  174.636933
# 9         188.0          1305           67.094253      72.151949  179.278161
# 10        191.0           652           66.997649      71.846159  184.791411
# 11        193.0           470           67.485141      72.459225  188.795745
# 12        195.0           211           67.425619      72.615373  196.464455

# %%
players_height.plot(y=['avg_overall_rating'],figsize=(12,5),title='Potential vs Height')
